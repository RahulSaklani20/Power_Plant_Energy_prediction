# %% [markdown]
# #EDA & Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv('Energy.production.csv')

# %%
data
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41
#
# [9568 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   temperature        9568 non-null   float64
#  1   exhaust_vacuum     9568 non-null   float64
#  2   amb_pressure       9568 non-null   float64
#  3   r_humidity         9568 non-null   float64
#  4   energy_production  9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
data.shape
# Out:
# (9568, 5)

# %%
data.describe()
# Out:
#        temperature  exhaust_vacuum  amb_pressure   r_humidity  \
# count  9568.000000     9568.000000   9568.000000  9568.000000
# mean     19.651231       54.305804   1013.259078    73.308978
# std       7.452473       12.707893      5.938784    14.600269
# min       1.810000       25.360000    992.890000    25.560000
# 25%      13.510000       41.740000   1009.100000    63.327500
# 50%      20.345000       52.080000   1012.940000    74.975000
# 75%      25.720000       66.540000   1017.260000    84.830000
# max      37.110000       81.560000   1033.300000   100.160000
#
#        energy_production
# count        9568.000000
# mean          454.365009
# std            17.066995
# min           420.260000
# 25%           439.750000
# 50%           451.550000
# 75%           468.430000
# max           495.760000

# %%
data.isnull().sum() #No null values.
# Out:
# temperature          0
# exhaust_vacuum       0
# amb_pressure         0
# r_humidity           0
# energy_production    0
# dtype: int64

# %%
plt.figure(figsize=(10,8))
cor = data.corr()
sn.heatmap(cor, annot=True)
# Out:
# <AxesSubplot:>

# %%
#Checking for outliers in the data.
columns = ['temperature','exhaust_vacuum','amb_pressure', 'r_humidity']
plt.figure(figsize=(15,10))
for i in range(0,4):
  plt.subplot(2,2,i+1)
  sn.boxplot(columns[i],data=data)
plt.show()
# Out:
# C:\Users\Rahul\anaconda3\envs\machinelearning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Rahul\anaconda3\envs\machinelearning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(15,10))
for i in range(0,4):
  plt.subplot(2,2,i+1)
  sn.distplot(data[columns[i]])
plt.show()
# Out:
# C:\Users\Rahul\anaconda3\envs\machinelearning\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Rahul\anaconda3\envs\machinelearning\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Ploting the pair plot to see the relationship between the variables.
sn.pairplot(data)

# %%
#Ploting the regression plots between the independent and dependent variables.
sn.lmplot(x='temperature', y='energy_production', data=data)

# %%
sn.lmplot(x='exhaust_vacuum', y='energy_production', data=data)

# %%
sn.lmplot(x='amb_pressure', y='energy_production', data=data)

# %%
sn.lmplot(x='r_humidity', y='energy_production', data=data)

# %%
#Defining X & Y values
x = data.drop(['energy_production'], axis=1)
y = data['energy_production']

# %%
x
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity
# 0            9.59           38.56       1017.01       60.10
# 1           12.04           42.34       1019.72       94.67
# 2           13.87           45.08       1024.42       81.69
# 3           13.72           54.30       1017.89       79.08
# 4           15.14           49.64       1023.78       75.00
# ...           ...             ...           ...         ...
# 9563        17.10           49.69       1005.53       81.82
# 9564        24.73           65.34       1015.42       52.80
# 9565        30.44           56.24       1005.19       56.24
# 9566        23.00           66.05       1020.61       80.29
# 9567        17.75           49.25       1020.86       63.67
#
# [9568 rows x 4 columns]

# %%
y
# Out:
# 0       481.30
# 1       465.36
# 2       465.48
# 3       467.05
# 4       463.58
#          ...
# 9563    457.32
# 9564    446.92
# 9565    429.34
# 9566    421.57
# 9567    454.41
# Name: energy_production, Length: 9568, dtype: float64

# %%
#Normalizing the data
from sklearn import preprocessing
data_norm = preprocessing.normalize(x)
names = ['temperature', 'exhaust_vacuum', 'amb_pressure', 'r_humidity']
x_norm = pd.DataFrame(data_norm, columns=names)
x_norm
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity
# 0        0.009406        0.037820      0.997500    0.058947
# 1        0.011746        0.041305      0.994800    0.092356
# 2        0.013482        0.043820      0.995787    0.079407
# 3        0.013418        0.053106      0.995499    0.077340
# 4        0.014730        0.048296      0.996055    0.072969
# ...           ...             ...           ...         ...
# 9563     0.016927        0.049187      0.995356    0.080992
# 9564     0.024264        0.064110      0.996302    0.051806
# 9565     0.030175        0.055750      0.996430    0.055750
# 9566     0.022414        0.064367      0.994602    0.078244
# 9567     0.017331        0.048087      0.996756    0.062167
#
# [9568 rows x 4 columns]

# %%
# performing the train test split on the data
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_norm,y,test_size=0.20, random_state=24)

# %%
x_train.head()
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity
# 8477     0.025549        0.057375      0.995597    0.069585
# 8131     0.021648        0.046137      0.997186    0.054975
# 1542     0.011917        0.039663      0.995786    0.081825
# 385      0.013716        0.041399      0.996785    0.067218
# 9465     0.024234        0.068433      0.994123    0.080300

# %%
y_train.head()
# Out:
# 8477    443.74
# 8131    451.92
# 1542    464.03
# 385     468.63
# 9465    438.10
# Name: energy_production, dtype: float64

# %%
x_test.head()
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity
# 486      0.023240        0.068855      0.993984    0.081940
# 6542     0.031061        0.078779      0.994816    0.056303
# 2977     0.012374        0.040909      0.994961    0.090698
# 2448     0.023874        0.058630      0.996100    0.061461
# 6190     0.011656        0.042507      0.995246    0.086847

# %%
#Conacting the dataframes x_train and y_train
df_ols = pd.concat([x_train, y_train], axis=1)
df_ols
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 8477     0.025549        0.057375      0.995597    0.069585             443.74
# 8131     0.021648        0.046137      0.997186    0.054975             451.92
# 1542     0.011917        0.039663      0.995786    0.081825             464.03
# 385      0.013716        0.041399      0.996785    0.067218             468.63
# 9465     0.024234        0.068433      0.994123    0.080300             438.10
# ...           ...             ...           ...         ...                ...
# 6500     0.029746        0.067078      0.996070    0.049599             431.25
# 5249     0.025154        0.066910      0.995608    0.060459             437.49
# 3473     0.004092        0.039339      0.994661    0.095321             491.22
# 8535     0.027164        0.066395      0.995662    0.059255             442.13
# 899      0.027056        0.048846      0.997616    0.040539             443.78
#
# [7654 rows x 5 columns]

# %% [markdown]
# # MLR Model

# %%
import statsmodels.formula.api as smf

# %%
mlr = smf.ols('energy_production~temperature+exhaust_vacuum+amb_pressure+r_humidity', data = df_ols).fit()

# %%
mlr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      energy_production   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 2.497e+04
# Date:                Sun, 10 Jul 2022   Prob (F-statistic):               0.00
# Time:                        10:35:47   Log-Likelihood:                -22464.
# No. Observations:                7654   AIC:                         4.494e+04
# Df Residuals:                    7649   BIC:                         4.497e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
y_pred = mlr.predict(x_test)

# %%
y_pred
# Out:
# 486     440.980770
# 6542    428.017206
# 2977    468.895357
# 2448    445.010916
# 6190    470.166033
#            ...
# 2511    444.242740
# 7637    439.893650
# 7674    436.481927
# 3322    464.030817
# 3228    472.146613
# Length: 1914, dtype: float64

# %%
#testing the accuracy of the linear regression model
from sklearn.metrics import mean_squared_error , mean_absolute_error

# %%
y_pred_train = mlr.predict(x_train)
y_pred_train
# Out:
# 8477    440.607246
# 8131    454.007673
# 1542    471.014503
# 385     468.876304
# 9465    439.289822
#            ...
# 6500    434.191178
# 5249    440.853518
# 3473    485.906033
# 8535    437.258827
# 899     446.144976
# Length: 7654, dtype: float64

# %%
#Training Error
mean_squared_error(y_train,y_pred_train)
# Out:
# 20.737045759633354

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 19.127052054548514

# %%
#Training error
mean_absolute_error(y_train, y_pred_train)
# Out:
# 3.6052337695725707

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3.577270209012543

# %%
rmse_mlr = np.sqrt(mean_squared_error(y_test,y_pred))
print(rmse_mlr)
# Out:
# 4.373448531142046

# %%
mlr_r_squared = mlr.rsquared
mlr_r_squared
# Out:
# 0.9288754976713904

# %% [markdown]
# # Lasso regression

# %%
from sklearn.linear_model import LassoCV
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
#defining cross-validation method to evaluate model
Lasso_cv = KFold(n_splits=10, random_state=24, shuffle=True)
Lasso_model_Kfold = LassoCV()

# %%
#useing LassoCV to evaluate model
Lasso_scores = cross_val_score(Lasso_model_Kfold, x, y, scoring='neg_mean_squared_error',
                         cv=Lasso_cv, n_jobs=-1)
Lasso_scores
# Out:
# array([-19.4860788 , -19.83701065, -22.89989849, -21.62819489,
#        -21.92514859, -20.73662307, -18.55734483, -21.93783409,
#        -19.95475547, -20.94932242])

# %%
Lasso_model_Kfold.fit(x, y)
# Out:
# LassoCV()

# %%
from numpy import mean
from numpy import absolute
from numpy import sqrt

# %%
#view RMSE
rmse_lasso = sqrt(mean(absolute(Lasso_scores)))
rmse_lasso
# Out:
# 4.559739151470063

# %%
#calculate R-squared of regression model
Lasso_r_squared = Lasso_model_Kfold.score(x, y)
Lasso_r_squared
# Out:
# 0.9286884621828044

# %% [markdown]
# #### Ridge regression

# %%
from sklearn.linear_model import RidgeCV

# %%
#defining cross-validation method to evaluate model
Ridge_cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %%
#defining model
Ridge_model_Kfold = RidgeCV()

# %%
Ridge_model_Kfold.fit(x, y)
# Out:
# RidgeCV()

# %%
#Evaluating the model
Ridge_scores = cross_val_score(Ridge_model_Kfold, x, y, scoring='neg_mean_squared_error',
                         cv=Ridge_cv, n_jobs=-1)
Ridge_scores
# Out:
# array([-20.44154573, -21.58760054, -22.0790245 , -20.93710648,
#        -21.83682326, -20.59124581, -19.96154202, -19.14852943,
#        -22.19823615, -19.19668657])

# %%
rmse_ridge = sqrt(mean(absolute(Ridge_scores)))
rmse_ridge
# Out:
# 4.560464236180439

# %%
#calculate R-squared of regression model
Ridge_r_squared = Ridge_model_Kfold.score(x, y)
Ridge_r_squared
# Out:
# 0.9286960883583302

# %% [markdown]
# #Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor(criterion='squared_error', max_depth = 5)
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
from sklearn import tree
tree.plot_tree(dtr)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[0] <= 0.017\nsquared_error = 291.56\nsamples = 7654\nvalue = 454.371'),
#  Text(0.25, 0.75, 'X[0] <= 0.011\nsquared_error = 87.716\nsamples = 3132\nvalue = 471.814'),
#  Text(0.125, 0.5833333333333334, 'X[0] <= 0.009\nsquared_error = 43.27\nsamples = 1387\nvalue = 479.597'),
#  Text(0.0625, 0.4166666666666667, 'X[0] <= 0.007\nsquared_error = 31.679\nsamples = 643\nvalue = 483.649'),
#  Text(0.03125, 0.25, 'X[0] <= 0.005\nsquared_error = 26.702\nsamples = 328\nvalue = 485.712'),
#  Text(0.015625, 0.08333333333333333, 'squared_error = 25.895\nsamples = 44\nvalue = 488.92'),
#  Text(0.046875, 0.08333333333333333, 'squared_error = 24.986\nsamples = 284\nvalue = 485.215'),
#  Text(0.09375, 0.25, 'X[2] <= 0.995\nsquared_error = 27.819\nsamples = 315\nvalue = 481.501'),
#  Text(0.078125, 0.08333333333333333, 'squared_error = 58.657\nsamples = 71\nvalue = 478.367'),
# ...

# %%
#Predicting testing data
y_pred = dtr.predict(x_test)

# %%
#predicting training data
y_pred_train=dtr.predict(x_train)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
#Training Errors
mean_squared_error(y_train, y_pred_train)
# Out:
# 18.509246109463614

# %%
#Testing Errors
mean_squared_error(y_test, y_pred)
# Out:
# 18.71814568939433

# %%
rmse_dtr = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
rmse_dtr
# Out:
# 4.3264472364047535

# %%
# r squared value on train data
dtr_r_squared = dtr.score(x_train,y_train)
dtr_r_squared
# Out:
# 0.9365164675203654

# %%
# r squared value on test data
dtr_r_squared = dtr.score(x_test,y_test)
dtr_r_squared
# Out:
# 0.9354590822656761

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
reg = SVR()
param_grid = [
              {'kernel':['rbf'],
               'gamma':[0.5,0.1,0.01],
               'C':[10,0.1,0.001,0.0001] 
              }
             ]
gsv = GridSearchCV(reg,param_grid,cv=10)
gsv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVR(),
#              param_grid=[{'C': [10, 0.1, 0.001, 0.0001],
#                           'gamma': [0.5, 0.1, 0.01], 'kernel': ['rbf']}])

# %%
gsv.best_params_ , gsv.best_score_
# Out:
# ({'C': 10, 'gamma': 0.5, 'kernel': 'rbf'}, 0.7030065958664605)

# %%
reg = SVR(C= 10, gamma = 0.5)
reg.fit(x_train , y_train)
y_pred = reg.predict(x_test)

# %%
rmse_svm = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
rmse_svm
# Out:
# 8.887133978758117

# %%
svm_r_squared = gsv.score(x_test,y_test)
svm_r_squared
# Out:
# 0.7276698230528929

# %% [markdown]
# # Random Forest

# %%
#Using the train-test-split data (Done in EDA) & building a Random Forest Regressor model.
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
rf = RandomForestRegressor(criterion='squared_error', max_depth = 5, random_state=24)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=5, random_state=24)

# %%
y_pred=rf.predict(x_test)

# %%
y_pred_train = rf.predict(x_train)

# %%
#Training Error (MSE)
mean_squared_error(y_train, y_pred_train)
# Out:
# 16.922475036479007

# %%
#Testing Error (RMSE)
rmse_rf =  np.sqrt(mean_squared_error(y_test,y_pred))
rmse_rf
# Out:
# 4.097734671953504

# %%
rf_r_squared = rf.score(x_test, y_test)
rf_r_squared
# Out:
# 0.9421024772312551

# %% [markdown]
# # Elastic Net regression

# %%
from sklearn.linear_model import ElasticNetCV

# %%
#define model
ElasticNet_model_Kfold = ElasticNetCV()

# %%
#define cross-validation method to evaluate model
ElasticNet_cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %%
#use LOOCV to evaluate model
ElasticNet_scores = cross_val_score(ElasticNet_model_Kfold, x, y, scoring='neg_mean_squared_error',
                         cv=ElasticNet_cv, n_jobs=-1)
ElasticNet_scores
# Out:
# array([-20.49973023, -21.66507582, -22.09035395, -20.8980904 ,
#        -21.83792376, -20.72880992, -19.98613794, -19.16587853,
#        -22.16896538, -19.16387185])

# %%
#view RMSE
rmse_elastic = sqrt(mean(absolute(ElasticNet_scores)))
rmse_elastic
# Out:
# 4.562946830399815

# %%
#fit model
ElasticNet_model_Kfold.fit(x, y)
# Out:
# ElasticNetCV()

# %%
#calculate R-squared of regression model
ElasticNet_r_squared = ElasticNet_model_Kfold.score(x, y)
ElasticNet_r_squared
# Out:
# 0.9286193579081377

# %% [markdown]
# # KNN

# %%
#Using GridSearch CV to get the optimal prarameters.
from sklearn.model_selection import GridSearchCV
from sklearn import neighbors
from sklearn.neighbors import KNeighborsRegressor

# %%
param_grid = [{'weights':['uniform', 'Distance'],'n_neighbors':[10,20,30,40,50]}]
grid = GridSearchCV(neighbors.KNeighborsRegressor(), param_grid)
grid.fit(x_train, y_train)
# Out:
# C:\Users\Rahul\anaconda3\envs\machinelearning\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Rahul\anaconda3\envs\machinelearning\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Rahul\anaconda3\envs\machinelearning\lib\site-packages\sklearn\neighbors\_regression.py", line 201, in fit
#     self.weights = _check_weights(self.weights)
# ...

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.9359865357937679
# {'n_neighbors': 10, 'weights': 'uniform'}

# %%
knn = KNeighborsRegressor(weights = 'uniform', n_neighbors = 10)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
#Predicting with the model.
y_pred=knn.predict(x_test)

# %%
y_pred_train=knn.predict(x_train)

# %%
#Testing Error
rmse_knn = np.sqrt(mean_squared_error(y_test,y_pred))
rmse_knn
# Out:
# 4.0431976161730425

# %%
#R-Square value
knn_r_squared = r2_score(y_test, y_pred)
knn_r_squared

#Or knn_r_squared = knn.score(x_test, y_test)
# Out:
# 0.9436333466391067

# %% [markdown]
# # Gaussian Naive Bayes

# %%
from sklearn.gaussian_process.kernels import (RBF, Matern, RationalQuadratic,ExpSineSquared, DotProduct,ConstantKernel)
from sklearn.gaussian_process import GaussianProcessRegressor

# %%
# Determination of the kernel used and the value lenght_scale at which the optimization process starts
kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-2, 1e3))

# %%
# Application of the regressor (alpha makes a statement about a possible noise of the training data)
gnb = GaussianProcessRegressor(kernel=kernel, alpha=0.1)
gnb.fit(x_train, y_train)
# Out:
# C:\Users\Rahul\anaconda3\envs\machinelearning\lib\site-packages\sklearn\gaussian_process\kernels.py:430: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\Rahul\anaconda3\envs\machinelearning\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# GaussianProcessRegressor(alpha=0.1, kernel=1**2 * RBF(length_scale=1))

# %%
# Prediction of the dependent variable for the test dataset
y_pred, sigma = gnb.predict(x_test, return_std=True)

# %%
#Testing Errors (MSE)
mean_squared_error(y_test, y_pred)
# Out:
# 15.699375424661579

# %%
#Testing Errors (RMSE)
rmse_gnb = np.sqrt(mean_squared_error(y_test,y_pred))
rmse_gnb
# Out:
# 3.9622437361502105

# %%
gnb_r_squared = gnb.score(x_test, y_test)
gnb_r_squared
# Out:
# 0.9458679233201259

# %% [markdown]
# ### XGBoost

# %%
from xgboost.sklearn import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from matplotlib.pyplot import clf
from sklearn.model_selection import RepeatedKFold

# %%
xgb = XGBRegressor()
parameters = {'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7],
              'n_estimators': [300]}

# %%
xgb_grid = GridSearchCV(xgb,
                        parameters,
                        cv = 5,
                        verbose=True)

# %%
xgb_grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [10:41:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:41:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:41:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:41:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:41:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
xgb_grid.best_params_ , gsv.best_score_
# Out:
# ({'learning_rate': 0.07,
#   'max_depth': 7,
#   'n_estimators': 300,
#   'objective': 'reg:linear'},
#  0.7030065958664605)

# %%
xgb = XGBRegressor(learning_rate=0.07,max_depth=7,objective='reg:linear', n_estimators=300)
xgb.fit(x_train , y_train)
y_pred = xgb.predict(x_test)
# Out:
# [10:42:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
mse_xgb = mean_squared_error(y_test,y_pred)

# %%
mse_xgb
# Out:
# 12.037495673086044

# %%
rmse_xgb = sqrt(mean_squared_error(y_test,y_pred))

# %%
rmse_xgb
# Out:
# 3.4695094283033794

# %%
mae_xgb = mean_absolute_error(y_test,y_pred)

# %%
mae_xgb
# Out:
# 2.6959710451004515

# %%
#R squared on test data
xgb_r_squared = xgb.score(x_test,y_test)
xgb_r_squared
# Out:
# 0.958494231701374

# %%
# Predicting data

# %%
Predicted_energy_production = pd.DataFrame(xgb.predict(x_test),columns=["predicted_energy_production"])

# %%
Predicted_energy_production
# Out:
#       predicted_energy_production
# 0                      438.280426
# 1                      432.665588
# 2                      466.462067
# 3                      445.599152
# 4                      471.002655
# ...                           ...
# 1909                   444.734436
# 1910                   434.274658
# 1911                   434.550720
# 1912                   467.121033
# 1913                   473.105927
#
# [1914 rows x 1 columns]

# %%
x_test = x_test.reset_index(drop=True)

# %%
y_test = y_test.reset_index(drop=True)

# %%
combined_data = pd.concat((x_test,y_test,
                           Predicted_energy_production), axis=1)

# %%
combined_data.head(25)
# Out:
#     temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production  \
# 0      0.023240        0.068855      0.993984    0.081940             435.21
# 1      0.031061        0.078779      0.994816    0.056303             431.69
# 2      0.012374        0.040909      0.994961    0.090698             461.46
# 3      0.023874        0.058630      0.996100    0.061461             440.66
# 4      0.011656        0.042507      0.995246    0.086847             471.98
# 5      0.009967        0.040512      0.995812    0.081356             480.11
# 6      0.014070        0.041761      0.995773    0.080592             465.89
# 7      0.007866        0.040912      0.996287    0.075343             485.13
# 8      0.017759        0.048278      0.996805    0.061097             462.60
# 9      0.012219        0.039929      0.995590    0.084002             465.74
# 10     0.021000        0.044335      0.997049    0.059041             452.75
# ...

# %%
# Visualizing actual and predicted value

# %%
sn.lmplot(x='predicted_energy_production', y='energy_production', data=combined_data)

# %% [markdown]
# # Artificial Neural Network

# %%
#Defining the X & Y values
X = data.drop(['energy_production'], axis=1)
Y = data['energy_production']

# %%
#Standardizing the X variables.
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
std_x = scaler.fit_transform(x)

# %%
# performing the train test split on the data
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(std_x,Y,test_size=0.20, random_state=24)

# %%
#importing libraries
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor

# %%
from tensorflow.keras.optimizers import Adam

# %%
#Defining the model.
def model_reg():
  model = Sequential()
  model.add(Dense(8, input_dim=4, kernel_initializer='uniform', activation='relu'))
  model.add(Dense(4, input_dim=4, kernel_initializer='uniform', activation='relu'))
  model.add(Dense(1, kernel_initializer='uniform', activation='linear'))

  opti = Adam(learning_rate=0.001)
  model.compile(loss='mean_squared_error', optimizer=opti, metrics=['mse'])
  return model

# %%
model1 = KerasRegressor(build_fn=model_reg, verbose=0)
batch_size=[10,20,50,100]
epochs=[40,70,100]
param_grid=dict(batch_size=batch_size, epochs=epochs)
grid = GridSearchCV(estimator = model1, param_grid = param_grid, cv = KFold(), verbose=10)
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_6280\216304177.py:1: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model1 = KerasRegressor(build_fn=model_reg, verbose=0)

# %%
grid_result = grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START batch_size=10, epochs=40...................................
# [CV 1/5; 1/12] END ..batch_size=10, epochs=40;, score=-22.029 total time=  26.2s
# [CV 2/5; 1/12] START batch_size=10, epochs=40...................................
# [CV 2/5; 1/12] END batch_size=10, epochs=40;, score=-185400.312 total time=  24.9s
# [CV 3/5; 1/12] START batch_size=10, epochs=40...................................
# [CV 3/5; 1/12] END ..batch_size=10, epochs=40;, score=-19.291 total time=  24.9s
# [CV 4/5; 1/12] START batch_size=10, epochs=40...................................
# [CV 4/5; 1/12] END ..batch_size=10, epochs=40;, score=-21.485 total time=  24.6s
# [CV 5/5; 1/12] START batch_size=10, epochs=40...................................
# [CV 5/5; 1/12] END ..batch_size=10, epochs=40;, score=-22.257 total time=  24.4s
# [CV 1/5; 2/12] START batch_size=10, epochs=70...................................
# ...

# %%
# Summarizing the results
print('Best:{}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best:-20.707905960083007, using {'batch_size': 20, 'epochs': 70}
# -37097.07484703064,74151.6188339181 with: {'batch_size': 10, 'epochs': 40}
# -21.171366119384764,1.304070669782837 with: {'batch_size': 10, 'epochs': 70}
# -21.582276916503908,1.29861934192889 with: {'batch_size': 10, 'epochs': 100}
# -20.981264495849608,1.3532729992651793 with: {'batch_size': 20, 'epochs': 40}
# -20.707905960083007,1.1862293761094316 with: {'batch_size': 20, 'epochs': 70}
# -21.295102310180663,0.49655386196492257 with: {'batch_size': 20, 'epochs': 100}
# -784.3995502471923,833.7739636427254 with: {'batch_size': 50, 'epochs': 40}
# -22.197035598754884,2.6555360378148483 with: {'batch_size': 50, 'epochs': 70}
# -39140.86915130615,78240.29199070824 with: {'batch_size': 50, 'epochs': 100}
# -12471.4224609375,5981.615203097241 with: {'batch_size': 100, 'epochs': 40}
# -532.5348693847657,246.86009916517799 with: {'batch_size': 100, 'epochs': 70}
# ...

# %% [markdown]
# ## Hyperparameter Tuning - learning Rate & Dropout Rate

# %%
from keras.layers import Dropout

# %%
def model_reg1(learning_rate,dropout_rate):
  model = Sequential()
  model.add(Dense(8, input_dim=4, kernel_initializer='uniform', activation='relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(4,input_dim=4, kernel_initializer='uniform', activation='relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(1, kernel_initializer='uniform', activation='linear'))

  opti = Adam(lr=learning_rate)
  model.compile(loss='mean_squared_error', optimizer=opti, metrics=['mse'] )
  return model

# %%
model2 = KerasRegressor(build_fn=model_reg1, verbose=0, batch_size=50, epochs=100)
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
param_grids = dict(learning_rate=learning_rate, dropout_rate=dropout_rate)
grid = GridSearchCV(estimator = model2,param_grid = param_grids,cv = KFold(),verbose = 10)
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_6280\2123697969.py:1: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model2 = KerasRegressor(build_fn=model_reg1, verbose=0, batch_size=50, epochs=100)

# %%
gird_result1 = grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# C:\Users\Rahul\anaconda3\envs\machinelearning\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-22.121 total time=  13.5s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 2/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-22.497 total time=  13.4s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 3/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-19.367 total time=  13.2s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 4/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-20.432 total time=  13.2s
# ...

# %%
print('Best : {}, using {}'.format(gird_result1.best_score_,gird_result1.best_params_))
means = gird_result1.cv_results_['mean_test_score']
stds = gird_result1.cv_results_['std_test_score']
params = gird_result1.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : -20.97602081298828, using {'dropout_rate': 0.0, 'learning_rate': 0.001}
# -20.97602081298828,1.163812044674628 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# -23.076053619384766,2.4769660462465577 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# -25.83174285888672,4.463739235787341 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# -395.0554931640625,81.94141103728991 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# -22788.03617248535,44493.776605641804 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# -40.263604736328126,7.09125746311742 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# -4132.0035400390625,3025.688313601551 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# -2890.659814453125,1608.3456203720825 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# -98.12772903442382,95.54173443759105 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# ## Hyperparameter Tuning - Activation Function & Kernel Initializer

# %%
# Defining the function
def model_reg2(activation_function,init):
  model = Sequential()
  model.add(Dense(8, input_dim=4, kernel_initializer=init, activation=activation_function))
  model.add(Dropout(0.0))
  model.add(Dense(4, input_dim=4, kernel_initializer=init, activation=activation_function))
  model.add(Dropout(0.0))
  model.add(Dense(1,activation='linear'))

  opti = Adam(learning_rate=0.001)
  model.compile(loss='mean_squared_error', optimizer=opti, metrics=['mse'])
  return model

# %%
model3 = KerasRegressor(build_fn=model_reg2,verbose=0, batch_size=50, epochs=100)
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']
param_grids = dict(activation_function = activation_function,init = init)
grid = GridSearchCV(estimator = model3,param_grid = param_grids,cv = KFold(),verbose = 10)
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_6280\709120156.py:1: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model3 = KerasRegressor(build_fn=model_reg2,verbose=0, batch_size=50, epochs=100)

# %%
grid_result2 = grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 1/5; 1/12] END activation_function=softmax, init=uniform;, score=-184409.359 total time=  14.3s
# [CV 2/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 2/5; 1/12] END activation_function=softmax, init=uniform;, score=-185197.078 total time=  13.7s
# [CV 3/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 3/5; 1/12] END activation_function=softmax, init=uniform;, score=-184531.000 total time=  13.4s
# [CV 4/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 4/5; 1/12] END activation_function=softmax, init=uniform;, score=-184225.281 total time=  13.7s
# [CV 5/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 5/5; 1/12] END activation_function=softmax, init=uniform;, score=-183252.656 total time=  13.4s
# ...

# %%
print('Best : {}, using {}'.format(grid_result2.best_score_,grid_result2.best_params_))
means = grid_result2.cv_results_['mean_test_score']
stds = grid_result2.cv_results_['std_test_score']
params = grid_result2.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : -21.059100341796874, using {'activation_function': 'relu', 'init': 'normal'}
# -184323.075,627.6813171338671 with: {'activation_function': 'softmax', 'init': 'uniform'}
# -184084.334375,343.07539452447617 with: {'activation_function': 'softmax', 'init': 'normal'}
# -184011.515625,499.39759394287984 with: {'activation_function': 'softmax', 'init': 'zero'}
# -21.299415588378906,1.344398970631272 with: {'activation_function': 'relu', 'init': 'uniform'}
# -21.059100341796874,1.0794190251175797 with: {'activation_function': 'relu', 'init': 'normal'}
# -195738.971875,380.2413047575842 with: {'activation_function': 'relu', 'init': 'zero'}
# -152179.7875,672.6478395670492 with: {'activation_function': 'tanh', 'init': 'uniform'}
# -152107.21875,342.314937314447 with: {'activation_function': 'tanh', 'init': 'normal'}
# -150904.796875,379.7202206837209 with: {'activation_function': 'tanh', 'init': 'zero'}
# ...

# %% [markdown]
# ## Hyperparameter Tuning - No. of Neurons in activation layer.

# %%
# Defining the model
def model_reg3(neuron1,neuron2):
  model = Sequential()
  model.add(Dense(neuron1, input_dim=4, kernel_initializer='normal', activation='relu'))
  model.add(Dropout(0.0))
  model.add(Dense(neuron2, input_dim=4, kernel_initializer='normal', activation='relu'))
  model.add(Dropout(0.0))
  model.add(Dense(1,activation='linear'))

  opti = Adam(learning_rate=0.001)
  model.compile(loss='mean_squared_error', optimizer=opti, metrics=['mse'])
  return model

# %%
model4 = KerasRegressor(build_fn=model_reg3,verbose=0, batch_size=50, epochs=100)
neuron1 = [4,8,16]
neuron2 = [2,4,8]
param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)
grid = GridSearchCV(estimator = model4,param_grid = param_grids,cv = KFold(),verbose = 10)
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_6280\1798541551.py:1: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model4 = KerasRegressor(build_fn=model_reg3,verbose=0, batch_size=50, epochs=100)

# %%
grid_results3 = grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/5; 1/9] END .......neuron1=4, neuron2=2;, score=-23.727 total time=  13.1s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END .......neuron1=4, neuron2=2;, score=-23.015 total time=  13.8s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/5; 1/9] END .......neuron1=4, neuron2=2;, score=-19.258 total time=  13.0s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 4/5; 1/9] END .......neuron1=4, neuron2=2;, score=-21.753 total time=  12.5s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 5/5; 1/9] END .......neuron1=4, neuron2=2;, score=-21.016 total time=  12.8s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# ...

# %%
print('Best : {}, using {}'.format(grid_results3.best_score_,grid_results3.best_params_))
means = grid_results3.cv_results_['mean_test_score']
stds = grid_results3.cv_results_['std_test_score']
params = grid_results3.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : -20.068854904174806, using {'neuron1': 16, 'neuron2': 8}
# -21.753544998168945,1.5657615420072701 with: {'neuron1': 4, 'neuron2': 2}
# -39141.06778488159,78240.19268095274 with: {'neuron1': 4, 'neuron2': 4}
# -21.307355880737305,1.1615444674706326 with: {'neuron1': 4, 'neuron2': 8}
# -20.84477310180664,0.7814850609214883 with: {'neuron1': 8, 'neuron2': 2}
# -21.326889038085938,1.1962862195357047 with: {'neuron1': 8, 'neuron2': 4}
# -39029.18904876709,78016.67892236508 with: {'neuron1': 8, 'neuron2': 8}
# -39242.08884277344,78442.25246859502 with: {'neuron1': 16, 'neuron2': 2}
# -20.117505264282226,0.9075301853767687 with: {'neuron1': 16, 'neuron2': 4}
# -20.068854904174806,1.0128362522563463 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# ## Training Model with optimum values of Hyperparameters

# %%
# Defining the final model
final_model = Sequential()
final_model.add(Dense(16, input_dim=4, kernel_initializer='normal', activation='relu'))
final_model.add(Dropout(0.0))
final_model.add(Dense(8, input_dim=4, kernel_initializer='normal', activation='relu'))
final_model.add(Dropout(0.0))
final_model.add(Dense(1,activation='linear'))
opti = Adam(learning_rate=0.001)
final_model.compile(loss='mean_squared_error', optimizer=opti, metrics=['mse'])

# %%
final_model.fit(X_train,Y_train, batch_size=20, epochs=70)
# Out:
# Epoch 1/70
# 383/383 [==============================] - 1s 1ms/step - loss: 192537.4688 - mse: 192537.4688
# Epoch 2/70
# 383/383 [==============================] - 0s 1ms/step - loss: 90333.3750 - mse: 90333.3750
# Epoch 3/70
# 383/383 [==============================] - 0s 1ms/step - loss: 25755.1523 - mse: 25755.1523
# Epoch 4/70
# 383/383 [==============================] - 0s 1ms/step - loss: 9469.0098 - mse: 9469.0098
# Epoch 5/70
# 383/383 [==============================] - 0s 1ms/step - loss: 3654.8220 - mse: 3654.8220
# Epoch 6/70
# 383/383 [==============================] - 0s 1ms/step - loss: 1727.2323 - mse: 1727.2323
# Epoch 7/70
# 383/383 [==============================] - 0s 1ms/step - loss: 1017.4478 - mse: 1017.4478
# Epoch 8/70
# 383/383 [==============================] - 0s 1ms/step - loss: 639.8350 - mse: 639.8349
# Epoch 9/70
# 383/383 [==============================] - 0s 1ms/step - loss: 390.0506 - mse: 390.0506
# Epoch 10/70
# ...

# %%
#Predicting the x_test data with the final model.

y_pred = final_model.predict(X_test)
# Out:
# 60/60 [==============================] - 0s 888us/step

# %%
y_pred_train = final_model.predict(X_train)
# Out:
# 240/240 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Training Error

# %%
rmse_train_ann = np.sqrt(mean_squared_error(Y_train,y_pred_train))
rmse_train_ann
# Out:
# 4.708755491258964

# %% [markdown]
# Testing Error

# %%
rmse_ann = sqrt(mean_squared_error(Y_test,y_pred))

# %%
rmse_ann
# Out:
# 4.550097392763414

# %%
ann_r_squared = r2_score(Y_test, y_pred)
ann_r_squared
# Out:
# 0.9286138930037847

# %% [markdown]
# # Comparing Models

# %%
models_data=[["Multi Linear Regression",rmse_mlr,mlr_r_squared],
             ["Lasso Regression",rmse_lasso,Lasso_r_squared],
             ["Ridge Regression",rmse_ridge,Ridge_r_squared],
             ["Decision Tree Regressor",rmse_dtr,dtr_r_squared],
             ["Support Vector Regressor",rmse_svm,svm_r_squared],
             ["XGBoost",rmse_xgb,xgb_r_squared],
             ["Artificial Neural Network",rmse_ann,ann_r_squared],
             ["Random Forest Regressor",rmse_rf,rf_r_squared],
             ["K Nearest Neighbour",rmse_knn,knn_r_squared],
             ["ElasticNet Regression",rmse_elastic,ElasticNet_r_squared],
             ["Gaussian Naive bayes",rmse_gnb,gnb_r_squared]]

models_data=pd.DataFrame(models_data,columns=['Models','RMSE','R Squared'])

# %%
models_data.sort_values(by=['RMSE'], ascending=True)
# Out:
#                        Models      RMSE  R Squared
# 5                     XGBoost  3.469509   0.958494
# 10       Gaussian Naive bayes  3.962244   0.945868
# 8         K Nearest Neighbour  4.043198   0.943633
# 7     Random Forest Regressor  4.097735   0.942102
# 3     Decision Tree Regressor  4.326447   0.935459
# 0     Multi Linear Regression  4.373449   0.928875
# 6   Artificial Neural Network  4.550097   0.928614
# 1            Lasso Regression  4.559739   0.928688
# 2            Ridge Regression  4.560464   0.928696
# 9       ElasticNet Regression  4.562947   0.928619
# 4    Support Vector Regressor  8.887134   0.727670

# %%
import pickle

#open a file where you want to store data
file=open('xgboost_models.pkl','wb')

#dump information to that file
pickle.dump(xgb,file)

# %%
#loading the save model
loaded_model= pickle.load(open('xgboost_model.pkl','rb'))

# %%
#checking the xgb model
input_data=(29.56,52.84,1006.09,42.17)
input_data_as_numpy_array=np.asarray(input_data)
input_data_reshape=input_data_as_numpy_array.reshape(1,-1)
prediction=xgb.predict(input_data_reshape)
print(prediction)
# Out:
# [425.7803]
